# %% [markdown]
# # If you happy and I know it you can enter my House
#
# You'll see how you can in a couple of hours build a deep learning algorithm.

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
import seaborn as sns
import h5py
from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Sequential

import pydot
from IPython.display import SVG


import keras.backend as K
K.set_image_data_format('channels_last')
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

# %%
def load_dataset(path_to_train, path_to_test):
    train_dataset = h5py.File(path_to_train)
    train_x = np.array(train_dataset['train_set_x'][:])
    train_y = np.array(train_dataset['train_set_y'][:])

    test_dataset = h5py.File(path_to_test)
    test_x = np.array(test_dataset['test_set_x'][:])
    test_y = np.array(test_dataset['test_set_y'][:])

    # y reshaped
    train_y = train_y.reshape((1, train_x.shape[0]))
    test_y = test_y.reshape((1, test_y.shape[0]))

    return train_x, train_y, test_x, test_y

# %% [markdown]
# This dataset can be used to solve the Happy House problem.
# Where, we allow a person to enter the house only if he/she is smiling!
# So, a smile detector!

# %% [markdown]
# ![Texte alternatif…](https://raw.githubusercontent.com/Kulbear/deep-learning-coursera/master/Convolutional%20Neural%20Networks/images/house-members.png)

# %% [markdown]
# Details of the "Happy" dataset:
#
# * Images are of shape (64,64,3)
# * Training: 600 pictures
# * Test: 150 pictures

# %% [markdown]
# # Load Dataset

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig = load_dataset("train_happy.h5","test_happy.h5")

# Normalize image vectors
X_train = X_train_orig/255.
X_test = X_test_orig/255.

# Reshape
Y_train = Y_train_orig.T
Y_test = Y_test_orig.T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 600
# number of test examples = 150
# X_train shape: (600, 64, 64, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 64, 64, 3)
# Y_test shape: (150, 1)

# %%
# Sample image from dataset
print("Image shape :",X_train_orig[10].shape)
imshow(X_train_orig[10])
# Out:
# Image shape : (64, 64, 3)

# %% [markdown]
# # Building Model

# %% [markdown]
# _________________________________________________________________
#
# conv2d_3 (Conv2D)            (None, 64, 64, 32)        4736
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 32769
# _________________________________________________________________

# %%
model = Sequential([Conv2D(filters=32, kernel_size=(7,7), activation='relu', padding='same',
                     input_shape=(64, 64, 3)),
                    BatchNormalization(),
                    MaxPooling2D(pool_size=(2,2)),
                    Flatten(),
                    Dense(units =1, activation='sigmoid') ])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 32)        4736
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 32769
# =================================================================
# Total params: 37,633
# Trainable params: 37,569
# Non-trainable params: 64
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=["accuracy"])

# %%
history_model = model.fit(X_train, Y_train,
                    batch_size=1,
                    epochs=5)
# Out:
# Epoch 1/5
# 600/600 [==============================] - 3s 4ms/step - loss: 0.6346 - accuracy: 0.6167
# Epoch 2/5
# 600/600 [==============================] - 2s 4ms/step - loss: 0.2931 - accuracy: 0.8933
# Epoch 3/5
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1769 - accuracy: 0.9467
# Epoch 4/5
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1201 - accuracy: 0.9567
# Epoch 5/5
# 600/600 [==============================] - 2s 4ms/step - loss: 0.1126 - accuracy: 0.9600

# %% [markdown]
# # Evaluate / Test

# %%
train_accuracy = history_model.history['accuracy']
train_loss = history_model.history['loss']

count = range(len(train_accuracy))
plt.plot(count, train_accuracy, label='Training accuracy')
plt.plot(count, train_loss, label='Training Loss')
plt.title('epochs vs Training Loss')
plt.legend()

# %% [markdown]
# Evaluate Test set

# %%
test_loss, test_accuracy = model.evaluate(X_test, Y_test, batch_size=32)
print('Test loss: %.4f accuracy: %.4f' % (test_loss, test_accuracy))
# Out:
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1529 - accuracy: 0.9533
# Test loss: 0.1529 accuracy: 0.9533

# %% [markdown]
# Confusion Matrix

# %%
Y_pred=model.predict(X_test)
for i in range(len(Y_pred)):
    Y_pred[i]=int(round(float(Y_pred[i]),0))
Y_pred = Y_pred.astype('int32')
confusion_matrix = pd.crosstab(pd.Series(Y_test.reshape(150)), Y_pred.reshape(150), rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
# Out:
# <AxesSubplot:xlabel='Predicted', ylabel='Actual'>

# %% [markdown]
# # Note
#
# Before you submit your work
#
# * You should compare different optimizers
#
# ---
#
# * Display images with Predicted & expected labels (Happy-sad)

# %%
optimizers=['SGD','RMSprop','Adam','Adadelta','Adagrad','Adamax','Nadam','Ftrl']
acc=[]
los=[]
for optimizer in optimizers:
    
    print("\n",optimizer,":")
    
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=["accuracy"])
    history_model = model.fit(X_train, Y_train,
                        batch_size=32,
                        epochs=5)
    train_accuracy = history_model.history['accuracy'][0]
    train_loss = history_model.history['loss'][0]
    
    acc.append(history_model.history['accuracy'][0])
    los.append(history_model.history['loss'][0])
# Out:
#  SGD :
# Epoch 1/5
# 19/19 [==============================] - 2s 85ms/step - loss: 0.0679 - accuracy: 0.9783
# Epoch 2/5
# 19/19 [==============================] - 2s 87ms/step - loss: 0.0547 - accuracy: 0.9900
# Epoch 3/5
# 19/19 [==============================] - 2s 82ms/step - loss: 0.0516 - accuracy: 0.9867
# Epoch 4/5
# 19/19 [==============================] - 1s 77ms/step - loss: 0.0491 - accuracy: 0.9883
# Epoch 5/5
# 19/19 [==============================] - 1s 77ms/step - loss: 0.0476 - accuracy: 0.9883
#
#  RMSprop :
# Epoch 1/5
# 19/19 [==============================] - 2s 90ms/step - loss: 0.0582 - accuracy: 0.9833
# Epoch 2/5
# 19/19 [==============================] - 1s 77ms/step - loss: 0.0493 - accuracy: 0.9900
# Epoch 3/5
# 19/19 [==============================] - 2s 81ms/step - loss: 0.0467 - accuracy: 0.9900
# Epoch 4/5
# 19/19 [==============================] - 2s 85ms/step - loss: 0.0414 - accuracy: 0.9900
# Epoch 5/5
# 19/19 [==============================] - 2s 83ms/step - loss: 0.0416 - accuracy: 0.9867
#
#  Adam :
# Epoch 1/5
# 19/19 [==============================] - 2s 76ms/step - loss: 0.0408 - accuracy: 0.9917
# Epoch 2/5
# 19/19 [==============================] - 2s 85ms/step - loss: 0.0391 - accuracy: 0.9867
# Epoch 3/5
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0320 - accuracy: 0.9917
# Epoch 4/5
# 19/19 [==============================] - 2s 85ms/step - loss: 0.0323 - accuracy: 0.9917
# Epoch 5/5
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0294 - accuracy: 0.9933
#
#  Adadelta :
# Epoch 1/5
# 19/19 [==============================] - 2s 76ms/step - loss: 0.0236 - accuracy: 0.9933
# Epoch 2/5
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0233 - accuracy: 0.9933
# Epoch 3/5
# 19/19 [==============================] - 1s 76ms/step - loss: 0.0232 - accuracy: 0.9933
# Epoch 4/5
# 19/19 [==============================] - 1s 76ms/step - loss: 0.0232 - accuracy: 0.9933
# Epoch 5/5
# 19/19 [==============================] - 1s 77ms/step - loss: 0.0232 - accuracy: 0.9933
#
#  Adagrad :
# Epoch 1/5
# 19/19 [==============================] - 2s 76ms/step - loss: 0.0229 - accuracy: 0.9933
# Epoch 2/5
# 19/19 [==============================] - 1s 77ms/step - loss: 0.0218 - accuracy: 0.9933
# Epoch 3/5
# 19/19 [==============================] - 1s 77ms/step - loss: 0.0218 - accuracy: 0.9933
# Epoch 4/5
# 19/19 [==============================] - 1s 75ms/step - loss: 0.0216 - accuracy: 0.9933
# Epoch 5/5
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0210 - accuracy: 0.9933
#
#  Adamax :
# Epoch 1/5
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0388 - accuracy: 0.9900
# Epoch 2/5
# 19/19 [==============================] - 2s 85ms/step - loss: 0.0231 - accuracy: 0.9933
# Epoch 3/5
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0213 - accuracy: 0.9933
# Epoch 4/5
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0198 - accuracy: 0.9950
# Epoch 5/5
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0205 - accuracy: 0.9933
#
#  Nadam :
# Epoch 1/5
# 19/19 [==============================] - 2s 88ms/step - loss: 0.0348 - accuracy: 0.9883
# Epoch 2/5
# 19/19 [==============================] - 2s 85ms/step - loss: 0.0220 - accuracy: 0.9950
# Epoch 3/5
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0204 - accuracy: 0.9967
# Epoch 4/5
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0212 - accuracy: 0.9950
# Epoch 5/5
# 19/19 [==============================] - 1s 76ms/step - loss: 0.0207 - accuracy: 0.9950
#
#  Ftrl :
# Epoch 1/5
# 19/19 [==============================] - 2s 75ms/step - loss: 0.6571 - accuracy: 0.5217
# Epoch 2/5
# 19/19 [==============================] - 2s 84ms/step - loss: 0.6932 - accuracy: 0.4800
# Epoch 3/5
# 19/19 [==============================] - 2s 79ms/step - loss: 0.6932 - accuracy: 0.4900
# Epoch 4/5
# 19/19 [==============================] - 1s 77ms/step - loss: 0.6932 - accuracy: 0.4900
# Epoch 5/5
# 19/19 [==============================] - 2s 83ms/step - loss: 0.6932 - accuracy: 0.4833

# %%
plt.bar(optimizers,acc)
plt.show()

# %%
plt.bar(optimizers,los)
plt.show()

# %%
labels=['not happy','happy']
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    
    img_index = np.random.randint(0, 149) 
    imshow(X_test[img_index])
    
    actual_label = int(Y_test[img_index])
    predicted_label = int(Y_pred[img_index])
    
    plt.xlabel("Actual: {} ({})\n Predicted: {} ({})".format(
        actual_label, labels[actual_label], predicted_label, labels[predicted_label]
    ))

plt.tight_layout()
plt.show()
